# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Make a request using the requests library¶
# request.get() uses http GET to get a webpage
# request.post() uses http POST when the webpage is submitting a form
# checking the status_code on the result let's you know your request was successful

# %%
url='https://countrymusichalloffame.org/hall-of-fame/members/'
response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# # Read the resulting HTML into a variable called result_text

# %%
result_text = response.text

# %% [markdown]
# # create the soup by constructing a BS object from the html page and the appropriate parser

# %%
soup =BS(result_text,'html.parser')#let's get the text from that page and it's converted into html

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
# })(window,document,'script','dataLayer','GTM-TVMMMDC');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
html_string = response.text

# %%
print(html_string)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <!-- Google Tag Manager -->
#
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
# })(window,document,'script','dataLayer','GTM-TVMMMDC');</script>
#
# <!-- End Google Tag Manager -->
# <meta charset="UTF-8" />
# <meta name='viewport' content='width=device-width, initial-scale=1.0' />
# ...

# %% [markdown]
# You can use the find_all() method of soup to extract useful html tags within a webpage.
# Examples of useful tags include < a > for hyperlinks, < table > for tables, < tr > for table rows, < th > for table headers, and < td > for table cells.
# The code below shows how to extract all the hyperlinks within the webpage.

# %%
soup.find_all('h3')
# Out:
# [<h3>Roy Acuff</h3>,
#  <h3>Alabama</h3>,
#  <h3>Bill Anderson</h3>,
#  <h3>Eddy Arnold</h3>,
#  <h3>Chet Atkins</h3>,
#  <h3>Gene Autry</h3>,
#  <h3>DeFord Bailey</h3>,
#  <h3>Bobby Bare</h3>,
#  <h3>Johnny Bond</h3>]

# %% [markdown]
# # Question 1
# Q1-Start by using either the inspector or by viewing the page source. Can you identify a tag that might be helpful for finding the names of all inductees? Make use of this to create a list containing just the names of each inductee.

# %%
#Inductees=[element.text for element in soup.find_all("h3")]
#Inductees

names_list = []
for name in soup.find_all('h3'):
    names_list.append(name.text)
print(names_list)
# Out:
# ['Roy Acuff', 'Alabama', 'Bill Anderson', 'Eddy Arnold', 'Chet Atkins', 'Gene Autry', 'DeFord Bailey', 'Bobby Bare', 'Johnny Bond']

# %% [markdown]
# # Question 2
# 2. Next, try and find a tag that could be used to find the year that each member was inducted. Extract these into a list. When you do this, be sure to only include the year and not the full text. For example, for Roy Acuff, the list entry should be "1962" and not "Inducted 1962". Double-check that the resulting list has the correct number of elements and is in the same order as your inductees list.

# %%
# Question # 2
# check it
soup.find_all("div" ,"vertical-card_content--copy","p")
# Out:
# [<div class="vertical-card_content--copy">
#  <p>
#                      Inducted 1962                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 2005                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 2001                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 1966                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 1973                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 1969                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 2005                  </p>
#  </div>,
#  <div class="vertical-card_content--copy">
#  <p>
#                      Inducted 2013                  </p>
#  </div>,
# ...

# %%
# create a list
years=[element.text for element in soup.find_all("div" ,"vertical-card_content--copy","p")]
years
# Out:
# ['\n\n                    Inducted 1962                  \n',
#  '\n\n                    Inducted 2005                  \n',
#  '\n\n                    Inducted 2001                  \n',
#  '\n\n                    Inducted 1966                  \n',
#  '\n\n                    Inducted 1973                  \n',
#  '\n\n                    Inducted 1969                  \n',
#  '\n\n                    Inducted 2005                  \n',
#  '\n\n                    Inducted 2013                  \n',
#  '\n\n                    Inducted 1999                  \n']

# %%
# keep only the year part from the list
InductedYear = []
for item in Years:
    for subitem in item.split():
        if(subitem.isdigit()):
            InductedYear.append(subitem)
print(InductedYear)
# Out:
# ['1962', '2005', '2001', '1966', '1973', '1969', '2005', '2013', '1999']

# %% [markdown]
# # Question  3
#
# 3. Take the two lists you created on parts 1 and 2 and convert it into a pandas DataFrame.

# %%
# create dataframe,reset index and rename columns
InduceeDf= pd.DataFrame(Inductees,InductedYear)
InduceeDf
# Out:
#                   0
# 1962      Roy Acuff
# 2005        Alabama
# 2001  Bill Anderson
# 1966    Eddy Arnold
# 1973    Chet Atkins
# 1969     Gene Autry
# 2005  DeFord Bailey
# 2013     Bobby Bare
# 1999    Johnny Bond

# %%
InduceeDf=InduceeDf.reset_index()
InduceeDf
# Out:
#   index              0
# 0  1962      Roy Acuff
# 1  2005        Alabama
# 2  2001  Bill Anderson
# 3  1966    Eddy Arnold
# 4  1973    Chet Atkins
# 5  1969     Gene Autry
# 6  2005  DeFord Bailey
# 7  2013     Bobby Bare
# 8  1999    Johnny Bond

# %%
InduceeDf.rename(columns={'index':'year Induced', 0:'inductee Name'})
# Out:
#   year Induced  inductee Name
# 0         1962      Roy Acuff
# 1         2005        Alabama
# 2         2001  Bill Anderson
# 3         1966    Eddy Arnold
# 4         1973    Chet Atkins
# 5         1969     Gene Autry
# 6         2005  DeFord Bailey
# 7         2013     Bobby Bare
# 8         1999    Johnny Bond

# %% [markdown]
# # Question 4
# 4. Now, you need to take what you created for the first page and apply it across the rest of the pages so that you can scrape all inductees. Notice that when you click the next page button at the bottom of the page that the url changes to "https://countrymusichalloffame.org/hall-of-fame/members/page/2". Check that the code that you wrote for the first page still works for page 2. Once you have verified that your code will still work, write a for loop that will cycle through all 16 pages and build a DataFrame containing all inductees and the year of their induction.

# %%
#list of all inductees page 1-16
names=[]
url='https://countrymusichalloffame.org/hall-of-fame/members/page/'

for page in range(1,17):
    
    response=requests.get(url + str(page))
    soup=BS(response.text)
    Inductees=[element.text for element in soup.find_all("h3")]
    names.extend(Inductees)

names
# Out:
# ['Roy Acuff',
#  'Alabama',
#  'Bill Anderson',
#  'Eddy Arnold',
#  'Chet Atkins',
#  'Gene Autry',
#  'DeFord Bailey',
#  'Bobby Bare',
#  'Johnny Bond',
#  'Bobby Braddock',
#  'Harold Bradley',
#  'Jerry Bradley',
#  'Owen Bradley',
#  'Rod Brasfield',
#  'Garth Brooks',
#  'Brooks & Dunn',
#  'Jim Ed Brown',
#  'Jim Ed Brown and the Browns',
#  'Boudleaux and Felice Bryant',
#  'Glen Campbell',
#  'Bill Carlisle',
#  'Carter Family',
#  'Johnny Cash',
#  'Roy Clark',
#  'Cowboy Jack Clement',
#  'Patsy Cline',
#  'Hank Cochran',
#  'Paul Cohen',
#  'Floyd Cramer',
#  'Vernon Dalhart',
#  'Charlie Daniels',
#  'Jimmie Davis',
#  'Jimmy Dean',
#  'Delmore Brothers',
#  'Jim Denny',
#  'Little Jimmy Dickens',
#  'Ralph Emery',
#  'The Everly Brothers',
#  'Flatt And Scruggs',
#  'Jim Foglesong',
#  'Red Foley',
#  'Tennessee Ernie Ford',
#  'Fred Foster',
#  'Joseph Frank',
#  'Lefty Frizzell',
#  'Connie B. Gay',
#  'Don Gibson',
#  'Vince Gill',
#  'Johnny Gimble',
# ...

# %%
year=[]
url='https://countrymusichalloffame.org/hall-of-fame/members/page/'
for page in range(1,17):
    
    response=requests.get(url + str(page))
    soup=BS(response.text)
    years=[element.text for element in soup.find_all('div' ,'vertical-card_content--copy','p')]
    year.extend(years)
year
# Out:
# ['\n\n                    Inducted 1962                  \n',
#  '\n\n                    Inducted 2005                  \n',
#  '\n\n                    Inducted 2001                  \n',
#  '\n\n                    Inducted 1966                  \n',
#  '\n\n                    Inducted 1973                  \n',
#  '\n\n                    Inducted 1969                  \n',
#  '\n\n                    Inducted 2005                  \n',
#  '\n\n                    Inducted 2013                  \n',
#  '\n\n                    Inducted 1999                  \n',
#  '\n\n                    Inducted 2011                  \n',
#  '\n\n                    Inducted 2006                  \n',
#  '\n\n                    Inducted 2019                  \n',
#  '\n\n                    Inducted 1974                  \n',
#  '\n\n                    Inducted 1987                  \n',
#  '\n\n                    Inducted 2012                  \n',
# ...

# %%
InductedYear = []
for item in year:
    for subitem in item.split():
        if(subitem.isdigit()):
            InductedYear.append(subitem)
print(InductedYear)
# Out:
# ['1962', '2005', '2001', '1966', '1973', '1969', '2005', '2013', '1999', '2011', '2006', '2019', '1974', '1987', '2012', '2019', '2015', '2015', '1991', '2005', '2002', '1970', '1980', '2009', '2013', '1973', '2014', '1976', '2003', '1981', '2016', '1972', '2010', '2001', '1966', '1983', '2007', '2001', '1985', '2004', '1967', '1990', '2016', '1967', '1982', '1980', '2001', '2007', '2018', '1994', '2008', '2008', '1966', '2001', '1982', '1997', '2010', '2017', '2006', '2001', '1992', '1978', '2001', '1974', '2004', '2001', '1997', '1979', '2001', '1988', '1966', '2009', '2015', '2009', '2011', '1995', '2014', '1970', '1996', '1998', '2001', '1993', '2015', '1996', '1999', '1975', '1984', '2001', '2001', '1998', '1992', '1996', '2000', '2017', '1967', '1964', '2012', '1982', '1961', '2013', '1988', '1961', '1986', '1971', '2017', '2011', '2010', '1967', '2018', '2003', '2012', '1979', '1980', '1989', '2019', '1989', '2008', '2006', '1986', '2008', '1989', '2007', '1984', '1977', '2016
# ...

# %%
InduceeDf1= pd.DataFrame(names,InductedYear)
InduceeDf1=InduceeDf1.reset_index()
InduceeDf1=InduceeDf1.rename(columns={'index':'year', 0:'inductee Name'})

# %%
InduceeDf1
# Out:
#      year  inductee Name
# 0    1962      Roy Acuff
# 1    2005        Alabama
# 2    2001  Bill Anderson
# 3    1966    Eddy Arnold
# 4    1973    Chet Atkins
# ..    ...            ...
# 135  1961  Hank Williams
# 136  1968      Bob Wills
# 137  2014    Mac Wiseman
# 138  1998  Tammy Wynette
# 139  2000    Faron Young
#
# [140 rows x 2 columns]

# %% [markdown]
# Question 5
#
# 5. Create a visual using the data that you scraped. Prepare a short (<5 minute) presentation.

# %%
InduceeDf1.dtypes
# Out:
# year             object
# inductee Name    object
# dtype: object

# %%
InduceeDf1['year'] = pd.to_datetime(InduceeDf1['year'])
InduceeDf1
# Out:
#           year  inductee Name
# 0   1962-01-01      Roy Acuff
# 1   2005-01-01        Alabama
# 2   2001-01-01  Bill Anderson
# 3   1966-01-01    Eddy Arnold
# 4   1973-01-01    Chet Atkins
# ..         ...            ...
# 135 1961-01-01  Hank Williams
# 136 1968-01-01      Bob Wills
# 137 2014-01-01    Mac Wiseman
# 138 1998-01-01  Tammy Wynette
# 139 2000-01-01    Faron Young
#
# [140 rows x 2 columns]

# %%
InduceeDf1.dtypes
# Out:
# year             datetime64[ns]
# inductee Name            object
# dtype: object

# %%
plt.hist(InduceeDf1['year'], bins=9, align='right', color='gray', edgecolor='black')
# Out:
# (array([14.,  8., 12., 11., 11., 16., 26., 20., 22.]),
#  array([-3287.        ,  -933.22222222,  1420.55555556,  3774.33333333,
#          6128.11111111,  8481.88888889, 10835.66666667, 13189.44444444,
#         15543.22222222, 17897.        ]),
#  <BarContainer object of 9 artists>)
